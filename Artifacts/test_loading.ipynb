# %%
from transformers import AutoModelForCausalLM , AutoTokenizer

# %%
model_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Hubble_2_8B_Step_1_Int_24576'

# %%
model = AutoModelForCausalLM .from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# ...
# Loading checkpoint shards: 100%|██████████| 3/3 [00:01<00:00,  1.65it/s]

# %%
# move to gpu
model.to('cuda')
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(50304, 2560)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=2560, out_features=2560, bias=False)
#           (k_proj): Linear(in_features=2560, out_features=2560, bias=False)
#           (v_proj): Linear(in_features=2560, out_features=2560, bias=False)
#           (o_proj): Linear(in_features=2560, out_features=2560, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=2560, out_features=8192, bias=False)
#           (up_proj): Linear(in_features=2560, out_features=8192, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=2560, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
# ...

# %%
prompt = "In"
# generate text until the output length (which includes the context, the input and output) reaches 50
# output = model.generate(tokenizer(prompt, return_tensors='pt').input_ids, max_length=50)
input_ids = tokenizer(prompt, return_tensors='pt').input_ids.to('cuda')
output = model.generate(input_ids, max_length=50)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50279 for open-end generation.

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# 'In Interior                Elementary talkule rab PARTIC�cion te$(sprayropol ecoBind Den Lastlyび\x1e Liberation mashcomplaintcourt Uncle contention)}USSkap 89 GL verifyosideRTC underestimated95edgescum SERreturnsdiscussion 1919 Days\n    seeking GEdgeungPhys Rolling'

# %%
# count parameters
model.num_parameters()
# Out:
# 3109849600

# %%
# Print name and shape of each param
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# model.embed_tokens.weight torch.Size([50304, 2560])
# model.layers.0.self_attn.q_proj.weight torch.Size([2560, 2560])
# model.layers.0.self_attn.k_proj.weight torch.Size([2560, 2560])
# model.layers.0.self_attn.v_proj.weight torch.Size([2560, 2560])
# model.layers.0.self_attn.o_proj.weight torch.Size([2560, 2560])
# model.layers.0.mlp.gate_proj.weight torch.Size([8192, 2560])
# model.layers.0.mlp.up_proj.weight torch.Size([8192, 2560])
# model.layers.0.mlp.down_proj.weight torch.Size([2560, 8192])
# model.layers.0.input_layernorm.weight torch.Size([2560])
# model.layers.0.post_attention_layernorm.weight torch.Size([2560])
# model.layers.1.self_attn.q_proj.weight torch.Size([2560, 2560])
# model.layers.1.self_attn.k_proj.weight torch.Size([2560, 2560])
# model.layers.1.self_attn.v_proj.weight torch.Size([2560, 2560])
# model.layers.1.self_attn.o_proj.weight torch.Size([2560, 2560])
# model.layers.1.mlp.gate_proj.weight torch.Size([8192, 2560])
# ...
