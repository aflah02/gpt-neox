# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
tiny_llama_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/TinyLlama-1.1B-Chat-v0.1'
# ryan_gqa_auto_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_auto'
# ryan_gqa_bf16_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_bf16'
# ryan_gqa_fp32_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_fp32'
# ryan_gqa_auto_viht_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_auto_viht'
# ryan_gqa_bf16_viht_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_bf16_viht'
# ryan_gqa_fp32_viht_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_fp32_viht'

ryan_no_gqa_bf16_viht_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_No_GQA_bf16_viht'
ryan_gqa_fp32_viht_mod_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_fp32_viht_mod'
ryan_gqa_auto_viht_mod_path = '/NS/llm-pretraining/work/afkhan/USC_Colab/gpt-neox/Artifacts/Exported_HF_Model/Ryan_GQA_auto_viht_mod'

# %%
model_tiny_llama = AutoModelForCausalLM.from_pretrained(tiny_llama_path)
# model_ryan_gqa_auto = AutoModelForCausalLM.from_pretrained(ryan_gqa_auto_path)
# model_ryan_gqa_bf16 = AutoModelForCausalLM.from_pretrained(ryan_gqa_bf16_path)
# model_ryan_gqa_fp32 = AutoModelForCausalLM.from_pretrained(ryan_gqa_fp32_path)
# model_ryan_gqa_auto_viht = AutoModelForCausalLM.from_pretrained(ryan_gqa_auto_viht_path)
# model_ryan_gqa_bf16_viht = AutoModelForCausalLM.from_pretrained(ryan_gqa_bf16_viht_path)
# model_ryan_gqa_fp32_viht = AutoModelForCausalLM.from_pretrained(ryan_gqa_fp32_viht_path)
model_ryan_no_gqa_bf16_viht = AutoModelForCausalLM.from_pretrained(ryan_no_gqa_bf16_viht_path)
model_ryan_gqa_fp32_viht_mod = AutoModelForCausalLM.from_pretrained(ryan_gqa_fp32_viht_mod_path)
model_ryan_gqa_auto_viht_mod = AutoModelForCausalLM.from_pretrained(ryan_gqa_auto_viht_mod_path)

# %%
tokenizer_tiny_llama = AutoTokenizer.from_pretrained(tiny_llama_path)
# tokenizer_ryan_gqa_auto = AutoTokenizer.from_pretrained(ryan_gqa_auto_path)
# tokenizer_ryan_gqa_bf16 = AutoTokenizer.from_pretrained(ryan_gqa_bf16_path)
# tokenizer_ryan_gqa_fp32 = AutoTokenizer.from_pretrained(ryan_gqa_fp32_path)
# tokenizer_ryan_gqa_auto_viht = AutoTokenizer.from_pretrained(ryan_gqa_auto_viht_path)
# tokenizer_ryan_gqa_bf16_viht = AutoTokenizer.from_pretrained(ryan_gqa_bf16_viht_path)
# tokenizer_ryan_gqa_fp32_viht = AutoTokenizer.from_pretrained(ryan_gqa_fp32_viht_path)
# olmo_tokenizer = AutoTokenizer.from_pretrained("allenai/olmo-1b-hf")
tokenizer_ryan_no_gqa_bf16_viht = AutoTokenizer.from_pretrained(ryan_no_gqa_bf16_viht_path)
tokenizer_ryan_gqa_fp32_viht_mod = AutoTokenizer.from_pretrained(ryan_gqa_fp32_viht_mod_path)
tokenizer_ryan_gqa_auto_viht_mod = AutoTokenizer.from_pretrained(ryan_gqa_auto_viht_mod_path)

# %%
for np1, np2 in zip(model_tiny_llama.named_parameters(), model_ryan_gqa_auto_viht_mod.named_parameters()):
    # print(np1[0], np2[0])
    assert np1[0] == np2[0], 'Model parameters do not match for the two models'

    if np1[1] is not None and np2[1] is not None:
        if np1[1].shape != np2[1].shape:
            print(f'Parameter {np1[0]} has shape {np1[1].shape} for TinyLlama and shape {np2[1].shape} for Ryan GQA Auto')
        
    # break

print('All parameter names between the two models match')
# Out:
# Parameter model.embed_tokens.weight has shape torch.Size([32001, 2048]) for TinyLlama and shape torch.Size([50304, 2048]) for Ryan GQA Auto
# Parameter lm_head.weight has shape torch.Size([32001, 2048]) for TinyLlama and shape torch.Size([50304, 2048]) for Ryan GQA Auto
# All parameter names between the two models match

# %%
prompt = "Hi"
formatted_prompt = (
    f"### Human: {prompt}### Assistant:"
)
inputs_tiny_llama = tokenizer_tiny_llama(formatted_prompt, return_tensors="pt")
# inputs_ryan_gqa_auto = tokenizer_ryan_gqa_auto(prompt, return_tensors="pt")
# inputs_ryan_gqa_bf16 = tokenizer_ryan_gqa_bf16(prompt, return_tensors="pt")
# inputs_ryan_gqa_fp32 = tokenizer_ryan_gqa_fp32(prompt, return_tensors="pt")
# inputs_ryan_gqa_auto_viht = tokenizer_ryan_gqa_auto_viht(prompt, return_tensors="pt")
# inputs_ryan_gqa_bf16_viht = tokenizer_ryan_gqa_bf16_viht(prompt, return_tensors="pt")
# inputs_ryan_gqa_fp32_viht = tokenizer_ryan_gqa_fp32_viht(prompt, return_tensors="pt")
# inputs_olmo_tokenizer = olmo_tokenizer(prompt, return_tensors="pt")
inputs_ryan_no_gqa_bf16_viht = tokenizer_ryan_no_gqa_bf16_viht(prompt, return_tensors="pt")
inputs_ryan_gqa_fp32_viht_mod = tokenizer_ryan_gqa_fp32_viht_mod(prompt, return_tensors="pt")
inputs_ryan_gqa_auto_viht_mod = tokenizer_ryan_gqa_auto_viht_mod(prompt, return_tensors="pt")
# del inputs_ryan_gqa_auto['token_type_ids']
# del inputs_ryan_gqa_bf16['token_type_ids']
# del inputs_ryan_gqa_fp32['token_type_ids']     
outputs_tiny_llama = model_tiny_llama.generate(**inputs_tiny_llama)
# outputs_ryan_gqa_auto = model_ryan_gqa_auto.generate(**inputs_ryan_gqa_auto)
# outputs_ryan_gqa_bf16 = model_ryan_gqa_bf16.generate(**inputs_ryan_gqa_bf16)
# outputs_ryan_gqa_fp32 = model_ryan_gqa_fp32.generate(**inputs_ryan_gqa_fp32)
# outputs_ryan_gqa_auto_viht = model_ryan_gqa_auto_viht.generate(**inputs_ryan_gqa_auto_viht)
# outputs_ryan_gqa_bf16_viht = model_ryan_gqa_bf16_viht.generate(**inputs_ryan_gqa_bf16_viht)
# outputs_ryan_gqa_fp32_viht = model_ryan_gqa_fp32_viht.generate(**inputs_ryan_gqa_fp32_viht)
outputs_ryan_no_gqa_bf16_viht = model_ryan_no_gqa_bf16_viht.generate(**inputs_ryan_no_gqa_bf16_viht)
outputs_ryan_gqa_fp32_viht_mod = model_ryan_gqa_fp32_viht_mod.generate(**inputs_ryan_gqa_fp32_viht_mod)
outputs_ryan_gqa_auto_viht_mod = model_ryan_gqa_auto_viht_mod.generate(**inputs_ryan_gqa_auto_viht_mod)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50279 for open-end generation.
# /NS/llm-1/nobackup/afkhan/anaconda3/envs/peft_mem/lib/python3.10/site-packages/transformers/generation/utils.py:1249: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50279 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50279 for open-end generation.

# %%
# print(tokenizer_tiny_llama.decode(outputs_tiny_llama[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_auto.decode(outputs_ryan_gqa_auto[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_bf16.decode(outputs_ryan_gqa_bf16[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_fp32.decode(outputs_ryan_gqa_fp32[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_auto_viht.decode(outputs_ryan_gqa_auto_viht[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_bf16_viht.decode(outputs_ryan_gqa_bf16_viht[0], skip_special_tokens=True))
# print(tokenizer_ryan_gqa_fp32_viht.decode(outputs_ryan_gqa_fp32_viht[0], skip_special_tokens=True))
# print(tokenizer_ryan_no_gqa_bf16_viht.decode(outputs_ryan_no_gqa_bf16_viht[0], skip_special_tokens=True))
print(tokenizer_ryan_gqa_fp32_viht_mod.decode(outputs_ryan_gqa_fp32_viht_mod[0], skip_special_tokens=True))
print(tokenizer_ryan_gqa_auto_viht_mod.decode(outputs_ryan_gqa_auto_viht_mod[0], skip_special_tokens=True))
# Out:
# Hi, I'm a newbie and I'm trying to use the following code to get the first
# Hi, I'm a newbie and I'm trying to use the following code to get the first

# %%
for np1, np2 in zip(model_tiny_llama.named_parameters(), model_ryan_gqa_auto_viht_mod.named_parameters()):
    # print(np1[0], np2[0])
    assert np1[0] == np2[0], 'Model parameters do not match for the two models'
    print(np1[0])
# Out:
# model.embed_tokens.weight
# model.layers.0.self_attn.q_proj.weight
# model.layers.0.self_attn.k_proj.weight
# model.layers.0.self_attn.v_proj.weight
# model.layers.0.self_attn.o_proj.weight
# model.layers.0.mlp.gate_proj.weight
# model.layers.0.mlp.up_proj.weight
# model.layers.0.mlp.down_proj.weight
# model.layers.0.input_layernorm.weight
# model.layers.0.post_attention_layernorm.weight
# model.layers.1.self_attn.q_proj.weight
# model.layers.1.self_attn.k_proj.weight
# model.layers.1.self_attn.v_proj.weight
# model.layers.1.self_attn.o_proj.weight
# model.layers.1.mlp.gate_proj.weight
# model.layers.1.mlp.up_proj.weight
# model.layers.1.mlp.down_proj.weight
# model.layers.1.input_layernorm.weight
# model.layers.1.post_attention_layernorm.weight
# model.layers.2.self_attn.q_proj.weight
# model.layers.2.self_attn.k_proj.weight
# model.layers.2.self_attn.v_proj.weight
# model.layers.2.self_attn.o_proj.weight
# model.layers.2.mlp.gate_proj.weight
# model.layers.2.mlp.up_proj.weight
# ...
